# %%
assert spark.sql("SELECT COUNT(*) FROM medallion_demo.silver.orders_clean WHERE order_id IS NULL").collect()[0][0] == 0
assert spark.sql("SELECT COUNT(*) FROM medallion_demo.silver.orders_clean WHERE quantity <= 0").collect()[0][0] == 0
