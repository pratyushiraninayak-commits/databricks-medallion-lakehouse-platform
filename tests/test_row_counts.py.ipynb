# %%
bronze = spark.sql("SELECT COUNT(*) c FROM medallion_demo.bronze.orders").collect()[0][0]
silver = spark.sql("SELECT COUNT(*) c FROM medallion_demo.silver.orders_clean").collect()[0][0]

assert silver <= bronze
